# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics

# %%
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='Month'>

# %%
# make x axis ticks
x_axis = np.arange(len(pyber_ride_df))
tickLocations = [value for value in x_axis]

plt.xticks(tickLocations, pyber_ride_df['Month'])
# Out:
# ([<matplotlib.axis.XTick at 0x1683b37d948>,
#   <matplotlib.axis.XTick at 0x1683b383f08>,
#   <matplotlib.axis.XTick at 0x1683b2e3d48>,
#   <matplotlib.axis.XTick at 0x1683b3dba88>,
#   <matplotlib.axis.XTick at 0x1683b3de988>,
#   <matplotlib.axis.XTick at 0x1683b3e3648>,
#   <matplotlib.axis.XTick at 0x1683b3e63c8>,
#   <matplotlib.axis.XTick at 0x1683b3e6d08>,
#   <matplotlib.axis.XTick at 0x1683b37df48>,
#   <matplotlib.axis.XTick at 0x1683b415408>,
#   <matplotlib.axis.XTick at 0x1683b412208>,
#   <matplotlib.axis.XTick at 0x1683b419308>],
#  [Text(0, 0, 'Jan'),
#   Text(1, 0, 'Feb'),
#   Text(2, 0, 'Mar'),
#   Text(3, 0, 'April'),
#   Text(4, 0, 'May'),
#   Text(5, 0, 'June'),
#   Text(6, 0, 'July'),
#   Text(7, 0, 'Aug'),
#   Text(8, 0, 'Sept'),
#   Text(9, 0, 'Oct'),
#   Text(10, 0, 'Nov'),
#   Text(11, 0, 'Dec')])

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="465">
# <AxesSubplot:xlabel='Month'>

# %%
# get standard deviation
stdev = statistics.stdev(pyber_ride_df['Avg. Fare ($USD)'])

pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar', yerr=stdev, capsize=3)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='Month'>

# %%
plt.yticks(np.arange(0, 55, 5))
plt.ylim(0, 60)
# Out:
# (0.0, 60.0)
